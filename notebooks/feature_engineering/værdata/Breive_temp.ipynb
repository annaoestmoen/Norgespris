# %% [markdown]
# # Frost API

# %% [markdown]
# ## Sett opp API-nøkkel

# %%
CLIENT_ID = "0fa358f8-1ba2-4c05-bff7-2977868375c2"

# %% [markdown]
# ## Definer Breive-koordinater

# %%
breive_coords = (59.57624, 7.28038)

# %% [markdown]
# ## Hent alle stasjoner og filtrer på koordinater

# %%
import requests
import pandas as pd
from geopy.distance import geodesic

# Hent alle stasjoner fra Frost
url_stations = "https://frost.met.no/sources/v0.jsonld"
response = requests.get(url_stations, auth=(CLIENT_ID,''))
stations = response.json()['data']

# Lag liste med stasjoner som har koordinater, og regn avstand til Breive
stations_list = []
for s in stations:
    if 'geometry' in s and 'coordinates' in s['geometry']:
        coords = (s['geometry']['coordinates'][1], s['geometry']['coordinates'][0])  # [lat, lon]
        distance = geodesic(breive_coords, coords).km
        stations_list.append({
            'id': s['id'],
            'name': s['name'],
            'distance_km': distance
        })

stations_df = pd.DataFrame(stations_list)
stations_df = stations_df.sort_values('distance_km')
stations_df.head(5)  # viser de 5 nærmeste stasjonene
# Out:
#            id              name  distance_km
# 1002  SN40880  HOVDEN - LUNDANE     6.174906
# 1719  SN40840     RV9 HOVDEN II     7.509339
# 227   SN40890         BREIDVATN     9.569694
# 22    SN40905         RV9 BJÅEN    12.209966
# 1996  SN46390        HOLMEVATN     13.595188

# %%
# Velg nærmeste stasjon
nearest_station = stations_df.iloc[0]['id']
print("Henter data fra stasjon:", nearest_station)
# Out:
# Henter data fra stasjon: SN40880

# %% [markdown]
# ## Sett ønsket periode og velg stasjon

# %%
vinter_periods = [
    ("2024-11-01T00:00:00Z", "2024-11-30T23:00:00Z"),
    ("2024-12-01T00:00:00Z", "2024-12-31T23:00:00Z"),
    ("2025-01-01T00:00:00Z", "2025-01-31T23:00:00Z"),
    ("2025-11-01T00:00:00Z", "2025-11-30T23:00:00Z"),
    ("2025-12-01T00:00:00Z", "2025-12-31T23:00:00Z"),
    ("2026-01-01T00:00:00Z", "2026-01-20T22:00:00Z")
]

# %% [markdown]
# Hent data fra Frost API

# %%
def fetch_weather(stasjon_id, start, end):

    elements = "air_temperature,wind_speed,sum(precipitation_amount PT1H)"

    url = f"https://frost.met.no/observations/v0.jsonld?sources={stasjon_id}&elements={elements}&referencetime={start}/{end}"

    response = requests.get(url, auth=(CLIENT_ID, ''))
    
    if response.status_code != 200:
        print("Feil:", response.status_code)
        return pd.DataFrame()
    
    data = response.json()
    observations = data.get('data', [])
    
    records = []

    for obs in observations:
        row = {"timestamp": obs.get('referenceTime')}
        
        for element in obs.get('observations', []):
            row[element['elementId']] = element.get('value')
        
        records.append(row)

    return pd.DataFrame(records)

# %% [markdown]
# Hent vinterperioder

# %%
def fetch_weather_periods_hourly(stasjon_id, periods):
    dfs = []

    for start, end in periods:
        df = fetch_weather(stasjon_id, start, end)
        dfs.append(df)

    if dfs:
        weather_df = pd.concat(dfs, ignore_index=True)

        weather_df['timestamp'] = pd.to_datetime(weather_df['timestamp'])

        weather_df_hourly = weather_df[weather_df['timestamp'].dt.minute == 0].copy()

        weather_df_hourly = weather_df_hourly.sort_values('timestamp').reset_index(drop=True)

        return weather_df_hourly
    
    else:
        return pd.DataFrame()

# %% [markdown]
# Hent data fra vintermånedene

# %%
weather_df_hourly = fetch_weather_periods_hourly(nearest_station, vinter_periods)
weather_df_hourly.head()
# Out:
#                   timestamp  air_temperature  wind_speed  \
# 0 2024-11-01 00:00:00+00:00              7.9         8.2
# 1 2024-11-01 01:00:00+00:00              7.6         6.1
# 2 2024-11-01 02:00:00+00:00              7.6         6.9
# 3 2024-11-01 03:00:00+00:00              5.9         8.4
# 4 2024-11-01 04:00:00+00:00              4.5         6.5
#
#    sum(precipitation_amount PT1H)
# 0                             0.6
# 1                             1.3
# 2                             2.2
# 3                             2.8
# 4                             1.1

# %% [markdown]
# ## Tidsformat

# %%
# Konverter til datetime hvis ikke gjort
weather_df_hourly['timestamp'] = pd.to_datetime(weather_df_hourly['timestamp'])

# Formater som '2025-01-18 09:00:00.0000000'
weather_df_hourly['timestamp'] = weather_df_hourly['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S.%f0')

weather_df_hourly.head()
# Out:
#                      timestamp  air_temperature  wind_speed  \
# 0  2024-11-01 00:00:00.0000000              7.9         8.2
# 1  2024-11-01 01:00:00.0000000              7.6         6.1
# 2  2024-11-01 02:00:00.0000000              7.6         6.9
# 3  2024-11-01 03:00:00.0000000              5.9         8.4
# 4  2024-11-01 04:00:00.0000000              4.5         6.5
#
#    sum(precipitation_amount PT1H)
# 0                             0.6
# 1                             1.3
# 2                             2.2
# 3                             2.8
# 4                             1.1

# %% [markdown]
# ## Lagre data til Azure Blob

# %%
import os
from dotenv import load_dotenv
from azure.storage.blob import BlobServiceClient
import io

load_dotenv()

connection_string = os.getenv("AZURE_STORAGE_CONNECTION_STRING")

blob_service_client = BlobServiceClient.from_connection_string(connection_string)

container_name = "vaerdata"
blob_name = "Breive_weather.csv"

blob_client = blob_service_client.get_blob_client(
    container=container_name,
    blob=blob_name
)

csv_buffer = io.StringIO()
weather_df_hourly.to_csv(csv_buffer, index=False)

blob_client.upload_blob(csv_buffer.getvalue(), overwrite=True)

print("CSV lagret i Azure Blob Storage!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 10
#       6 load_dotenv()
#       8 connection_string = os.getenv("AZURE_STORAGE_CONNECTION_STRING")
# ---> 10 blob_service_client = BlobServiceClient.from_connection_string(connection_string)
#      12 container_name = "vaerdata"
#      13 blob_name = "Breive_weather.csv"
#
# File /opt/anaconda3/envs/bachelor2026/lib/python3.11/site-packages/azure/storage/blob/_blob_service_client.py:221, in BlobServiceClient.from_connection_string(cls, conn_str, credential, **kwargs)
#     161 @classmethod
#     162 def from_connection_string(
#     163     cls, conn_str: str,
#     164     credential: Optional[Union[str, Dict[str, str], "AzureNamedKeyCredential", "AzureSasCredential", "TokenCredential"]] = None,  # pylint: disable=line-too-long
#     165     **kwargs: Any
#     166 ) -> Self:
#     167     """Create BlobServiceClient from a Connection String.
#     168
#     169     :param str conn_str:
#    (...)    219             :caption: Creating the BlobServiceClient from a connection string.
#     220     """
# --> 221     account_url, secondary, credential = parse_connection_str(conn_str, credential, 'blob')
#     222     if 'secondary_hostname' not in kwargs:
#     223         kwargs['secondary_hostname'] = secondary
#
# File /opt/anaconda3/envs/bachelor2026/lib/python3.11/site-packages/azure/storage/blob/_shared/base_client.py:414, in parse_connection_str(conn_str, credential, service)
#     405 def parse_connection_str(
#     406     conn_str: str,
#     407     credential: Optional[Union[str, Dict[str, str], AzureNamedKeyCredential, AzureSasCredential, TokenCredential]],
#    (...)    412     Optional[Union[str, Dict[str, str], AzureNamedKeyCredential, AzureSasCredential, TokenCredential]],
#     413 ]:
# --> 414     conn_str = conn_str.rstrip(";")
#     415     conn_settings_list = [s.split("=", 1) for s in conn_str.split(";")]
#     416     if any(len(tup) != 2 for tup in conn_settings_list):
#
# AttributeError: 'NoneType' object has no attribute 'rstrip'
