# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("strom_regresjon") \
    .getOrCreate()

spark

data_path = "https://saprojectnorgesprisdev.blob.core.windows.net/processeddata/BREIVE_processed.csv"

df = spark.read.parquet(data_path)

df.printSchema()
df.show(5)
